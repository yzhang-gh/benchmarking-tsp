# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

from matplotlib.ticker import PercentFormatter

plt.rc("savefig", bbox="tight")
plt.rc("xtick", direction="in")
plt.rc("ytick", direction="in")

# %%
data_n50_rue = {
    "POMO": np.loadtxt("test_results/test_20220615_10_n50_rue_pomo/POMO/rue50_opts_0_multi_run_gaps.txt"),
    "POMO x8": np.loadtxt("test_results/test_20220615_10_n50_rue_pomo/POMO/rue50_opts_1_multi_run_gaps.txt"),
    "DACT": np.loadtxt("test_results/test_20220615_00_n50_rue_dact/DACT/rue50_opts_0_multi_run_gaps.txt").mean(axis=0),
    "DACT x4": np.loadtxt("test_results/test_20220615_15_n50_rue_dact/DACT/rue50_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH": np.loadtxt("test_results/test_20220622_193459_n50_rue_nlkh/NeuroLKH/rue50_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_1/testing/rue50/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_1/testing/rue50/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_n50_clust = {
    "POMO": np.loadtxt("test_results/test_20220616_155141_n50_clust_pomo/POMO/clust50_opts_0_multi_run_gaps.txt"),
    "POMO x8": np.loadtxt("test_results/test_20220616_155141_n50_clust_pomo/POMO/clust50_opts_1_multi_run_gaps.txt"),
    "DACT": np.loadtxt("test_results/test_20220617_104123_n50_clust_dact/DACT/clust50_opts_0_multi_run_gaps.txt").mean(axis=0),
    "DACT x4": np.loadtxt("test_results/test_20220617_160906_n50_clust_dact/DACT/clust50_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH": np.loadtxt("test_results/test_20220622_222147_n50_clust_nlkh/NeuroLKH/clust50_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_1/testing/cluster50/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_1/testing/cluster50/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_n100_rue = {
    "POMO": np.loadtxt("test_results/test_20220616_153546_n100_rue_pomo/POMO/rue100_opts_0_multi_run_gaps.txt"),
    "POMO x8": np.loadtxt("test_results/test_20220616_153546_n100_rue_pomo/POMO/rue100_opts_1_multi_run_gaps.txt"),
    "DACT": np.loadtxt("test_results/test_20220616_170023_n100_rue_dact/DACT/rue100_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH": np.loadtxt("test_results/test_20220622_220429_n100_rue_nlkh/NeuroLKH/rue100_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_1/testing/rue100/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_1/testing/rue100/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_n100_clust = {
    "POMO": np.loadtxt("test_results/test_20220616_155547_n100_clust_pomo/POMO/clust100_opts_2_multi_run_gaps.txt"),
    "POMO x8": np.loadtxt("test_results/test_20220616_155547_n100_clust_pomo/POMO/clust100_opts_3_multi_run_gaps.txt"),
    "DACT": np.loadtxt("test_results/test_20220617_162953_n100_clust_dact/DACT/clust100_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH": np.loadtxt("test_results/test_20220622_230247_n100_clust_nlkh/NeuroLKH/clust100_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_1/testing/cluster100/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_1/testing/cluster100/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_table1 = {
    "rue-50": data_n50_rue,
    "clust-50": data_n50_clust,
    "rue-100": data_n100_rue,
    "clust-100": data_n100_clust,
}

with open("data_table1.pkl", "wb") as wb:
    pickle.dump(data_table1, wb)

for dataset_id, data in data_table1.items():
    print(dataset_id)
    for model, d in data.items():
        print(f"{model:12} {d.mean():.6%}")
    print()
# Out:
# rue-50
# POMO         0.118478%
# POMO x8      0.022775%
# DACT         0.016656%
# DACT x4      0.000615%
# NeuroLKH     0.000261%
# LKH          0.003453%
# EAX          0.000001%
#
# clust-50
# POMO         0.135349%
# POMO x8      0.021305%
# DACT         0.176999%
# DACT x4      0.057606%
# NeuroLKH     0.000394%
# LKH          0.002245%
# EAX          0.000000%
#
# rue-100
# POMO         0.364633%
# POMO x8      0.127821%
# DACT         0.659637%
# NeuroLKH     0.000382%
# LKH          0.004440%
# EAX          0.000008%
#
# clust-100
# POMO         0.431809%
# POMO x8      0.140459%
# DACT         1.221983%
# NeuroLKH     0.002117%
# LKH          0.004756%
# EAX          0.000000%

# %%
data_n500_rue = {
    "NeuroLKH": np.loadtxt("test_results/test_20220623_155601_n500_rue_nlkh/NeuroLKH/rue500_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_2/testing/rue500/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH tuned": np.load("test_results_lkh_eax/exp_2/testing/rue500/LKH-tuned/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_2/testing/rue500/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_n1000_rue = {
    "NeuroLKH": np.loadtxt("test_results/test_20220624_020817_n1000_rue_nlkh/NeuroLKH/rue1000_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_2/testing/rue1000/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH tuned": np.load("test_results_lkh_eax/exp_2/testing/rue1000/LKH-tuned/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_2/testing/rue1000/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_n500_clust = {
    "NeuroLKH": np.loadtxt("test_results/test_20220623_163853_n500_clust_nlkh/NeuroLKH/clust500_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_2/testing/cluster500/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH tuned": np.load("test_results_lkh_eax/exp_2/testing/cluster500/LKH-tuned/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_2/testing/cluster500/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_n1000_clust = {
    "NeuroLKH": np.loadtxt("test_results/test_20220624_114122_n1000_clust_nlkh/NeuroLKH/clust1000_opts_0_multi_run_gaps.txt").mean(axis=0),
    "LKH": np.load("test_results_lkh_eax/exp_2/testing/cluster1000/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH tuned": np.load("test_results_lkh_eax/exp_2/testing/cluster1000/LKH-tuned/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "EAX": np.load("test_results_lkh_eax/exp_2/testing/cluster1000/EAX/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
}

data_table2_rue = {
    "rue-500": data_n500_rue,
    "rue-1000": data_n1000_rue,
}

data_table2_clust = {
    "clust-500": data_n500_clust,
    "clust-1000": data_n1000_clust,
}

with open("data_table2_rue.pkl", "wb") as wb:
    pickle.dump(data_table2_rue, wb)

for dataset_id, data in data_table2_rue.items():
    print(dataset_id)
    for model, d in data.items():
        print(f"{model:12} {d.mean():.6%}")
    print()

with open("data_table2_clust.pkl", "wb") as wb:
    pickle.dump(data_table2_clust, wb)

for dataset_id, data in data_table2_clust.items():
    print(dataset_id)
    for model, d in data.items():
        print(f"{model:12} {d.mean():.6%}")
    print()
# Out:
# rue-500
# NeuroLKH     0.000273%
# LKH          0.004356%
# LKH tuned    0.000086%
# EAX          0.000140%
#
# rue-1000
# NeuroLKH     0.000417%
# LKH          0.003620%
# LKH tuned    0.001732%
# EAX          0.000182%
#
# clust-500
# NeuroLKH     0.018080%
# LKH          0.042779%
# LKH tuned    0.000345%
# EAX          0.000006%
#
# clust-1000
# NeuroLKH     0.018599%
# LKH          0.018761%
# LKH tuned    0.000460%
# EAX          0.000086%

# %%
data_n100_rue = {
    "POMO (rue)": np.loadtxt("test_results/test_20220618_110054_n100_rue_dact_pomo/POMO/rue100_opts_0_multi_run_gaps.txt"),
    "POMO (clust)": np.loadtxt("test_results/test_20220618_110054_n100_rue_dact_pomo/POMO/rue100_opts_1_multi_run_gaps.txt"),
    "POMO (mix)": np.loadtxt("test_results/test_20220623_195305_n100_rue_pomo/POMO/rue100_opts_0_multi_run_gaps.txt"),
    "DACT (rue)": np.loadtxt("test_results/test_20220618_110054_n100_rue_dact_pomo/DACT/rue100_opts_0_multi_run_gaps.txt").mean(axis=0),
    "DACT (clust)": np.loadtxt("test_results/test_20220618_110054_n100_rue_dact_pomo/DACT/rue100_opts_1_multi_run_gaps.txt").mean(axis=0),
    # "DACT (mix)": np.loadtxt("test_results/test_20220620_154548_n100_rue_dact/DACT/rue100_opts_0_multi_run_gaps.txt").mean(axis=0),
}

data_n100_clust = {
    "POMO (rue)": np.loadtxt("test_results/test_20220619_215713_n100_clust_dact_pomo/POMO/clust100_opts_0_multi_run_gaps.txt"),
    "POMO (clust)": np.loadtxt("test_results/test_20220619_215713_n100_clust_dact_pomo/POMO/clust100_opts_1_multi_run_gaps.txt"),
    "POMO (mix)": np.loadtxt("test_results/test_20220623_195516_n100_clust_pomo/POMO/clust100_opts_0_multi_run_gaps.txt"),
    "DACT (rue)": np.loadtxt("test_results/test_20220619_215713_n100_clust_dact_pomo/DACT/clust100_opts_0_multi_run_gaps.txt").mean(axis=0),
    "DACT (clust)": np.loadtxt("test_results/test_20220617_162953_n100_clust_dact/DACT/clust100_opts_0_multi_run_gaps.txt").mean(axis=0),
    # "DACT (mix)": np.loadtxt("test_results/test_20220621_003732_n100_clust_dact/DACT/clust100_opts_0_multi_run_gaps.txt").mean(axis=0),
}

data_table3_n100 = {
    "rue-100": data_n100_rue,
    "clust-100": data_n100_clust,
}

with open("data_table3_n100.pkl", "wb") as wb:
    pickle.dump(data_table3_n100, wb)

for dataset_id, data in data_table3_n100.items():
    print(dataset_id)
    for model, d in data.items():
        print(f"{model:12} {d.mean():.6%}")
    print()
# Out:
# rue-100
# POMO (rue)   0.127821%
# POMO (clust) 0.923406%
# POMO (mix)   0.242010%
# DACT (rue)   0.661248%
# DACT (clust) 1.609123%
#
# clust-100
# POMO (rue)   0.377879%
# POMO (clust) 0.140459%
# POMO (mix)   0.121520%
# DACT (rue)   1.870169%
# DACT (clust) 1.221983%

# %%
data_n1000_rue = {
    "LKH (rue)": np.load("test_results_lkh_eax/exp_2/testing/rue1000/LKH-tuned/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH (clust)": np.load("test_results_lkh_eax/exp_2/testing/train_cluster1000_testing_rue1000/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH (mix)": np.load("test_results_lkh_eax/exp_2/testing/train_mix_testing_rue1000/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "NeuroLKH (rue)": np.loadtxt("test_results/test_20220618_130602_n1000_rue_nlkh/NeuroLKH/rue1000_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH (clust)": np.loadtxt("test_results/test_20220618_130602_n1000_rue_nlkh/NeuroLKH/rue1000_opts_2_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH (mix)": np.loadtxt("test_results/test_20220618_130602_n1000_rue_nlkh/NeuroLKH/rue1000_opts_1_multi_run_gaps.txt").mean(axis=0),
}

data_n1000_clust = {
    "LKH (rue)": np.load("test_results_lkh_eax/exp_2/testing/train_rue1000_testing_cluster1000/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH (clust)": np.load("test_results_lkh_eax/exp_2/testing/cluster1000/LKH-tuned/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "LKH (mix)": np.load("test_results_lkh_eax/exp_2/testing/train_mix_testing_cluster1000/LKH/PARHYDRA/performance.npy")["quality"].mean(axis=0) / 100,
    "NeuroLKH (rue)": np.loadtxt("test_results/test_20220619_003705_n1000_clust_nlkh/NeuroLKH/clust1000_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH (clust)": np.loadtxt("test_results/test_20220624_114122_n1000_clust_nlkh/NeuroLKH/clust1000_opts_0_multi_run_gaps.txt").mean(axis=0),
    "NeuroLKH (mix)": np.loadtxt("test_results/test_20220619_155256_n1000_clust_nlkh/NeuroLKH/clust1000_opts_0_multi_run_gaps.txt").mean(axis=0),
}

data_table3_n1000 = {
    "rue-1000": data_n1000_rue,
    "clust-1000": data_n1000_clust,
}

with open("data_table3_n1000.pkl", "wb") as wb:
    pickle.dump(data_table3_n1000, wb)

for dataset_id, data in data_table3_n1000.items():
    print(dataset_id)
    for model, d in data.items():
        print(f"{model:16} {d.mean():.6%}")
    print()
# Out:
# rue-1000
# LKH (rue)        0.001732%
# LKH (clust)      0.004530%
# LKH (mix)        0.004329%
# NeuroLKH (rue)   0.000381%
# NeuroLKH (clust) 0.001813%
# NeuroLKH (mix)   0.000354%
#
# clust-1000
# LKH (rue)        0.004530%
# LKH (clust)      0.000460%
# LKH (mix)        0.004119%
# NeuroLKH (rue)   0.029968%
# NeuroLKH (clust) 0.018599%
# NeuroLKH (mix)   0.020329%

# %%
data_n100_rue = {
    "POMO": np.loadtxt("test_results/test_20220621_111342_n100_rue_pomo/POMO/rue100_opts_0_multi_run_gaps.txt"),
    "DACT": np.loadtxt("test_results/test_20220621_001715_n100_rue_dact/DACT/rue100_opts_0_multi_run_gaps.txt").mean(axis=0),
}

data_n100_clust = {
    "POMO": np.loadtxt("test_results/test_20220621_111641_n100_clust_pomo/POMO/clust100_opts_0_multi_run_gaps.txt"),
    "DACT": np.loadtxt("test_results/test_20220621_100218_n100_clust_dact/DACT/clust100_opts_0_multi_run_gaps.txt").mean(axis=0),
}

data_table4 = {
    "rue-100": data_n100_rue,
    "clust-100": data_n100_clust,
}

with open("data_table4.pkl", "wb") as wb:
    pickle.dump(data_table4, wb)

for dataset_id, data in data_table4.items():
    print(dataset_id)
    for model, d in data.items():
        print(f"{model:16} {d.mean():.6%}")
    print()
# Out:
# rue-100
# POMO             0.670349%
# DACT             27.543740%
#
# clust-100
# POMO             0.682904%
# DACT             21.463013%

# %%
flierprops = dict(marker='.', markerfacecolor='black', markeredgecolor='none', markersize=3, alpha=0.5)

data_collection = data_table1
num_data_dist = len(data_collection.keys())
fig, axes = plt.subplots(1, num_data_dist, sharey=True, figsize=(4 * num_data_dist, 3.2), constrained_layout=True, gridspec_kw={"wspace": 0.04})
for ax, (dataset_id, data) in zip(axes.flatten(), data_collection.items()):
    ax.boxplot(data.values(), flierprops=flierprops)
    ax.set_xticklabels(data.keys(), rotation=30)
    ax.yaxis.set_major_formatter(PercentFormatter(xmax=1))
    ax.set_title(dataset_id)
    ax.grid(axis="y", alpha=0.4)
fig.savefig("test.png", dpi=200)
